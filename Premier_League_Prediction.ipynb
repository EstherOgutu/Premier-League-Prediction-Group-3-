# %% [markdown]
# <a href="https://colab.research.google.com/github/EstherOgutu/Premier-League-Prediction-Group-3-/blob/main/Premier_League_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PREDICTION FOR THE 2022/2023 PREMIER LEAGUE WINNER

# %% [markdown]
# ##1. Defining the Question

# %% [markdown]
# ### a) Specifying the Data Analytic Question

# %% [markdown]
# ###b) Defining the Metric of Success

# %% [markdown]
# ###c) Understanding the Context

# %% [markdown]
# ###d) Recording the Experimental Data

# %% [markdown]
# ###e) Data Relevance

# %% [markdown]
# ##2. Reading the Data

# %%
#Importing the Libraries that we will use

# Importing Numpy
import numpy as np

# Importing Pandas
import pandas as pd

# Importing Matplotlib
import matplotlib.pyplot as plt

# Importing Seaborn
import seaborn as sns

# Loading the Data from the source
season19=pd.read_csv('season-1819.csv')
season20=pd.read_csv('season-1920.csv')
season21=pd.read_csv('season-2021.csv')

# %% [markdown]
# ##3) Checking the Data

# %%
# Checking the number of rows and columns
print(season19.shape)
print(season20.shape)
print(season21.shape)
# Out:
# (380, 62)
# (380, 106)
# (380, 106)

# %%
# Previewing the first five records
season19.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0   H  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55
# 1   H  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88
# 2   A  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62
# 3   A  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24
# 4   A  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74
#
#    PSCD  PSCA
# 0  4.07  7.69
# 1  3.61  4.70
# ...

# %%
# Previewing the first five records
season20.head()
# Out:
#   Div        Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0  E0  09/08/2019  20:00       Liverpool           Norwich     4     1   H
# 1  E0  10/08/2019  12:30        West Ham          Man City     0     5   A
# 2  E0  10/08/2019  15:00     Bournemouth  Sheffield United     1     1   D
# 3  E0  10/08/2019  15:00         Burnley       Southampton     3     0   H
# 4  E0  10/08/2019  15:00  Crystal Palace           Everton     0     0   D
#
#    HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     4     0  ...     3.43 -2.25      1.91      1.99   1.94   1.98     1.99
# 1     0     1  ...     2.91  1.75      1.95      1.95   1.96   1.97     2.07
# 2     0     0  ...     1.92 -0.50      1.95      1.95   1.98   1.95     2.00
# 3     0     0  ...     1.71  0.00      1.87      2.03   1.89   2.03     1.90
# 4     0     0  ...     1.71  0.25      1.82      2.08   1.97   1.96     2.03
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
# Previewing the first five records
season21.head()
# Out:
#   Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  12/09/2020  12:30          Fulham      Arsenal     0     3   A     0
# 1  E0  12/09/2020  15:00  Crystal Palace  Southampton     1     0   H     1
# 2  E0  12/09/2020  17:30       Liverpool        Leeds     4     3   H     3
# 3  E0  12/09/2020  20:00        West Ham    Newcastle     0     2   A     0
# 4  E0  13/09/2020  14:00       West Brom    Leicester     0     3   A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.84  0.75      2.01      1.89   2.02   1.91     2.13
# 1     0  ...     1.70  0.25      1.78      2.13   1.79   2.17     1.85
# 2     2  ...     2.62 -1.50      1.85      2.05   1.85   2.08     1.90
# 3     0  ...     1.92 -0.50      2.03      1.87   2.04   1.88     2.09
# 4     0  ...     1.73  0.25      1.92      1.98   1.93   1.99     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.92     2.02     1.87
# ...

# %%
# Previewing the last five records
season19.tail()
# Out:
#     Div        Date     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 375  E0  12/05/2019    Liverpool        Wolves     2     0   H     1     0
# 376  E0  12/05/2019   Man United       Cardiff     0     2   A     0     1
# 377  E0  12/05/2019  Southampton  Huddersfield     1     1   D     1     0
# 378  E0  12/05/2019    Tottenham       Everton     2     2   D     1     0
# 379  E0  12/05/2019      Watford      West Ham     1     4   A     0     2
#
#     HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 375   H  ...     2.31    22   -1.5     1.98     1.91     2.01     1.95  1.32
# 376   A  ...     2.95    21   -2.0     2.52     2.32     1.72     1.64  1.30
# 377   H  ...     2.29    22   -1.5     2.27     2.16     1.80     1.73  1.37
# 378   H  ...     2.07    19   -0.5     2.13     2.08     1.85     1.80  1.91
# 379   A  ...     2.44    19   -0.5     2.25     2.19     1.78     1.72  2.11
#
#      PSCD  PSCA
# 375  5.89  9.48
# 376  6.06  9.71
# ...

# %%
# Previewing the last five records
season20.tail()
# Out:
#     Div        Date   Time     HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 375  E0  26/07/2020  16:00    Leicester        Man United     0     2   A
# 376  E0  26/07/2020  16:00     Man City           Norwich     5     0   H
# 377  E0  26/07/2020  16:00    Newcastle         Liverpool     1     3   A
# 378  E0  26/07/2020  16:00  Southampton  Sheffield United     3     1   H
# 379  E0  26/07/2020  16:00     West Ham       Aston Villa     1     1   D
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 375     0     0  ...     2.03  0.50      1.89      2.01   1.88   2.05
# 376     2     0  ...     5.77 -3.75      2.03      1.87   2.01   1.88
# 377     1     1  ...     2.40  1.00      1.94      1.96   1.95   1.97
# 378     0     1  ...     2.01 -0.50      1.97      1.93   2.00   1.93
# 379     0     0  ...     2.03  0.00      1.93      1.97   1.95   1.98
#
#      MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 375     1.94     2.05     1.86     2.02
# ...

# %%
# Previewing the last five records
season21.tail()
# Out:
#     Div        Date   Time          HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 375  E0  23/05/2021  16:00         Liverpool  Crystal Palace     2     0   H
# 376  E0  23/05/2021  16:00          Man City         Everton     5     0   H
# 377  E0  23/05/2021  16:00  Sheffield United         Burnley     1     0   H
# 378  E0  23/05/2021  16:00          West Ham     Southampton     3     0   H
# 379  E0  23/05/2021  16:00            Wolves      Man United     1     2   A
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 375     1     0  ...     3.49 -2.25      1.86      2.04   1.88   2.03
# 376     2     0  ...     2.77 -1.75      2.01      1.89   1.99   1.89
# 377     1     0  ...     2.05  0.00      2.04      1.86   2.05   1.86
# 378     2     0  ...     2.14 -0.75      2.00      1.90   2.02   1.91
# 379     1     2  ...     1.62 -0.25      2.04      1.86   2.10   1.84
#
#      MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 375     1.98     2.14     1.88     2.00
# ...

# %%
# Checking all the columns have the appropriate Datatype
season19.dtypes
# Out:
# Div          object
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG          int64
#              ...
# BbMxAHA     float64
# BbAvAHA     float64
# PSCH        float64
# PSCD        float64
# PSCA        float64
# Length: 62, dtype: object

# %%
# Checking all the columns have the appropriate Datatype
season20.dtypes
# Out:
# Div          object
# Date         object
# Time         object
# HomeTeam     object
# AwayTeam     object
#              ...
# PCAHA       float64
# MaxCAHH     float64
# MaxCAHA     float64
# AvgCAHH     float64
# AvgCAHA     float64
# Length: 106, dtype: object

# %%
# Checking all the columns have the appropriate Datatype
season21.dtypes
# Out:
# Div          object
# Date         object
# Time         object
# HomeTeam     object
# AwayTeam     object
#              ...
# PCAHA       float64
# MaxCAHH     float64
# MaxCAHA     float64
# AvgCAHH     float64
# AvgCAHA     float64
# Length: 106, dtype: object

# %%
# Checking the information about the Dataset
season19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 62 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       380 non-null    object
#  1   Date      380 non-null    object
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  Referee   380 non-null    object
#  11  HS        380 non-null    int64
#  12  AS        380 non-null    int64
#  13  HST       380 non-null    int64
#  14  AST       380 non-null    int64
#  15  HF        380 non-null    int64
#  16  AF        380 non-null    int64
#  17  HC        380 non-null    int64
#  18  AC        380 non-null    int64
#  19  HY        380 non-null    int64
# ...

# %%
# Checking the information about the Dataset
season20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 106 entries, Div to AvgCAHA
# dtypes: float64(82), int64(16), object(8)
# memory usage: 314.8+ KB

# %%
# Checking the information about the Dataset
season21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 106 entries, Div to AvgCAHA
# dtypes: float64(82), int64(16), object(8)
# memory usage: 314.8+ KB

# %%
# Checking the statistical information of the numerical values in our Dataset
season19.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.568421    1.252632    0.678947    0.573684   14.134211   11.144737
# std      1.312836    1.180031    0.860802    0.766958    5.855371    4.654002
# min      0.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    8.000000
# 50%      1.000000    1.000000    0.000000    0.000000   14.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   18.000000   14.000000
# max      6.000000    6.000000    4.000000    3.000000   36.000000   25.000000
#
#               HST         AST          HF          AF  ...    BbAv<2.5  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     4.778947    3.928947   10.152632   10.305263  ...    2.126895
# ...

# %%
# Checking the statistical information of the numerical values in our Dataset
season20.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.515789    1.205263    0.700000    0.550000   13.323684   11.400000
# std      1.248646    1.200252    0.886427    0.758505    5.417938    5.255278
# min      0.000000    0.000000    0.000000    0.000000    2.000000    1.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    8.000000
# 50%      1.000000    1.000000    0.000000    0.000000   13.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   16.000000   14.000000
# max      8.000000    9.000000    5.000000    5.000000   31.000000   26.000000
#
#               HST         AST          HF          AF  ...    AvgC<2.5  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     4.555263    3.994737   10.484211   10.981579  ...    2.174132
# ...

# %%
# Checking the statistical information of the numerical values in our Dataset
season21.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.352632    1.342105    0.665789    0.605263   12.815789   11.363158
# std      1.320378    1.257722    0.825956    0.806945    5.490482    4.880602
# min      0.000000    0.000000    0.000000    0.000000    1.000000    1.000000
# 25%      0.000000    0.000000    0.000000    0.000000    9.000000    8.000000
# 50%      1.000000    1.000000    0.000000    0.000000   12.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   16.000000   14.250000
# max      9.000000    7.000000    4.000000    4.000000   29.000000   28.000000
#
#               HST         AST          HF          AF  ...    AvgC<2.5  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     4.544737    4.084211   11.223684   10.550000  ...    2.062421
# ...
